# %% [markdown]
# # ECE 143 Final Project Setup

# %% [markdown]
# ## Data Source
# - TBD

# %% [markdown]
# ## Research Question
# - TBD

# %% [markdown]
# ## Initial EDA
# - TBD

# %%
# Imports
import numpy as np
import pandas as pd

# %%
# Data loading (placeholder)
# df = pd.read_csv('path/to/data.csv')
# df.head()
